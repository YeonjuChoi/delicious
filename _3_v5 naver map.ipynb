# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup

# %%
rest_list = ['동경산책', '서울테이블', '황홀경', '텐동요츠야', '모힝 낙성대점', '박명주브라더', '에그썸', '온고지신', '마이무', '프랑스홍합집', '오지 편한식당', '용마커피', '쥬벤쿠바', '맨프롬오키나와', '메이드바이아린', '옷살', '모다모다', '시골집', '카페프레임', '제주상회', '더멜팅팟', '토끼네마굿간', '모단걸응접실', '도리도리하찌 닭도리탕', '아띠85도씨베이커리', '순보보', '코코미', '미분당', '미각담다', '오늘그대와', '까까', '우리가참순대', '혼네', '라티놀', '펭귄제과', '분짜 하노이', '쟝블랑제리', '아모르미오', '미미청', '쿠모식당', '미드레벨', '소블리', '프로젝트서울', '카페미엘', '티라노', '샤로스톤', '면화당', '삼차', '스시스캔들', '엘 따뻬오', '와인창고잡', '땅콩카페', '커피볶는여자', '진주상회', '호타루', '쭈앤쭈', '새우당', '너구리덮밥', '봉천예술관', '씨앗양식', '기절초풍왕순대', '다이조부', '히토리 더 야끼니꾸', '방콕야시장', '로향양꼬치 2호점', '소풍가는날', '딸랏롯빠이', '원초족본능', '오드비', '나에게오는길', '사케바히토리', '새실정원', 'Beck', '동네아저씨치킨', '망원동티라미수 샤로수길점', '황토방', '더고기 서울대본점', '쁘띠크', '오른손푸드카페', 'BANJO', '차이나당', '서울대곱창', '대중주점', '모던보이작업실', '미카엘', '막걸리카페잡', '바닐라스카이', '성민양꼬치 2호점', '마왕족발 샤로수길점', '할리스커피 서울대사거리점', '현씨공방', '참새방앗간', '오인자아구찜', '샤로수 흑돈', '엔조', '연탄부락 낙성대점', '고봉식당', '옛날육개장', '엉클비', '스타벅스 서울대입구역점', '고기야', '도스타코스 서울대입구역점', '홍콩반점0410 관악구청점', 'Newyork In Jinbar', '나는남자닭', '신선설농탕 서울대역점', '아비정전', '소우주', '카페 블리스', '제리', '만화경', '김창일스시', '코젤다크하우스 샤로수길점', '한우육회마을 2호점', '깐족깐족', '딱좋아', '미스리부자아줌마', '스월링', '사시사철 흑염소오리', '낙성기사식당', '생활맥주 서울대입구역점', '화상손만두', '무삥과 팟타이', '외래향 서울대점', '이상범스시', '탐앤탐스 서울대입구점', '정육식당 솔', '더은교', '도모다찌', '잇쇼쿠', '엘리펀트키친', '정가네 감자탕', '마담봉봉', '육회포차', '사운드마인드', '우동요츠야']
review_list = []

# %%
for x in rest_list:
    try:
        driver = webdriver.Chrome("./chromedriver\/chromedriver.exe")
        driver.get("https://map.naver.com/v5/search")
        time.sleep(3)
        search_box = driver.find_element_by_xpath('/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div[1]/div/input')
        search_box.send_keys(x)
        search_box.send_keys(Keys.ENTER)
        time.sleep(5)
        driver.switch_to.frame("entryIframe")
        review_list.append([rest_list.index(x),x, driver.find_element_by_xpath('//*[@id="app-root"]/div/div[2]/div[1]/div/div/div[1]').text])
        driver.quit()
    except:
        driver.quit()
        review_list.append([rest_list.index(x),x, "클릭 필요"])

# %%
#식당 한 곳을 대상으로 먼저 크롤러 만들어보기
driver = webdriver.Chrome("./chromedriver\/chromedriver.exe")
driver.get("https://map.naver.com/v5/search")
time.sleep(3)
search_box = driver.find_element_by_xpath('/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div[1]/div/input')
search_box.send_keys("동경산책")
search_box.send_keys(Keys.ENTER)
time.sleep(3)
driver.find_element_by_xpath('//*[@id="sidebar"]/navbar/perfect-scrollbar/div/div[3]/div').click()
driver.switch_to.frame("searchIframe")
click_name = driver.find_elements_by_xpath('/html/body/div[3]/div/div/div[1]/ul/li/div[2]/div[1]/a/span[1]')
click_name[2].click()
time.sleep(5)
driver.switch_to.default_content()
driver.switch_to.frame("entryIframe")
driver.find_element_by_xpath('//*[@id="app-root"]/div/div[2]/div[1]/div/div/div[1]').text
# Out:
# '동경산책일식당\n4.39/5방문자리뷰 353블로그리뷰 680'

# %%
#크롤링한 데이터 저장
review_list = [[0, '동경산책', '클릭 필요'], [1, '서울테이블', '클릭 필요'], [2, '황홀경', '클릭 필요'], [3, '텐동요츠야', '클릭 필요'], [4, '모힝 낙성대점', '모힝 낙성대점양식\n4.65/5방문자리뷰 1,904블로그리뷰 1726'], [5, '박명주브라더', '클릭 필요'], [6, '에그썸', '클릭 필요'], [7, '온고지신', '클릭 필요'], [8, '마이무', '클릭 필요'], [9, '프랑스홍합집', '클릭 필요'], [10, '오지 편한식당', '오지 편한식당요리주점\n4.67/5방문자리뷰 63블로그리뷰 169'], [11, '용마커피', '클릭 필요'], [12, '쥬벤쿠바', '쥬벤쿠바양식\n4.67/5방문자리뷰 844블로그리뷰 537'], [13, '맨프롬오키나와', '맨프롬오키나와바(BAR)\n4.25/5방문자리뷰 32블로그리뷰 45'], [14, '메이드바이아린', '메이드바이아린베이커리\n4.52/5방문자리뷰 138블로그리뷰 249'], [15, '옷살', '클릭 필요'], [16, '모다모다', '클릭 필요'], [17, '시골집', '클릭 필요'], [18, '카페프레임', '클릭 필요'], [19, '제주상회', '클릭 필요'], [20, '더멜팅팟', '클릭 필요'], [21, '토끼네마굿간', '토끼네마굿간이탈리아음식\n4.62/5방문자리뷰 757블로그리뷰 352'], [22, '모단걸응접실', '모단걸응접실양식\n4.13/5방문자리뷰 60블로그리뷰 372'], [23, '도리도리하찌 닭도리탕', '클릭 필요'], [24, '아띠85도씨베이커리', '아띠85도씨베이커리베이커리\n4.35/5방문자리뷰 374블로그리뷰 356'], [25, '순보보', '순보보한식\n4.49/5방문자리뷰 79블로그리뷰 170'], [26, '코코미', '클릭 필요'], [27, '미분당', '클릭 필요'], [28, '미각담다', '미각담다한식\n4.28/5방문자리뷰 25블로그리뷰 55'], [29, '오늘그대와', '클릭 필요'], [30, '까까', '클릭 필요'], [31, '우리가참순대', '우리가참순대순대,순댓국\n4.43/5방문자리뷰 199블로그리뷰 313'], [32, '혼네', '클릭 필요'], [33, '라티놀', '클릭 필요'], [34, '펭귄제과', '클릭 필요'], [35, '분짜 하노이', '클릭 필요'], [36, '쟝블랑제리', '쟝블랑제리베이커리\n4.43/5방문자리뷰 6,823블로그리뷰 2664'], [37, '아모르미오', '클릭 필요'], [38, '미미청', '미미청중식당\n4.35/5방문자리뷰 77블로그리뷰 366'], [39, '쿠모식당', '클릭 필요'], [40, '미드레벨', '미드레벨카페,디저트\n4.31/5방문자리뷰 139블로그리뷰 769'], [41, '소블리', '클릭 필요'], [42, '프로젝트서울', '클릭 필요'], [43, '카페미엘', '클릭 필요'], [44, '티라노', '클릭 필요'], [45, '샤로스톤', '클릭 필요'], [46, '면화당', '면화당아시아음식\n4.14/5방문자리뷰 58블로그리뷰 211'], [47, '삼차', '클릭 필요'], [48, '스시스캔들', '스시스캔들초밥,롤\n4.47/5방문자리뷰 63블로그리뷰 147'], [49, '엘 따뻬오', '엘 따뻬오스페인음식\n4.59/5방문자리뷰 269블로그리뷰 227'], [50, '와인창고잡', '와인창고잡와인\n4.3/5방문자리뷰 69블로그리뷰 119'], [51, '땅콩카페', '클릭 필요'], [52, '커피볶는여자', '커피볶는여자카페,디저트\n4.43/5방문자리뷰 187블로그리뷰 242'], [53, '진주상회', '클릭 필요'], [54, '호타루', '클릭 필요'], [55, '쭈앤쭈', '쭈앤쭈한식\n4.21/5방문자리뷰 87블로그리뷰 288'], [56, '새우당', '새우당해물,생선요리\n4.36/5방문자리뷰 187블로그리뷰 612'], [57, '너구리덮밥', '너구리덮밥덮밥\n3.8/5방문자리뷰 120블로그리뷰 424'], [58, '봉천예술관', '봉천예술관술집\n4.18/5방문자리뷰 42블로그리뷰 84'], [59, '씨앗양식', '클릭 필요'], [60, '기절초풍왕순대', '기절초풍왕순대순대,순댓국\n4.43/5방문자리뷰 287블로그리뷰 218'], [61, '다이조부', '클릭 필요'], [62, '히토리 더 야끼니꾸', '히토리 더 야끼니꾸소고기구이\n4.28/5방문자리뷰 23블로그리뷰 75'], [63, '방콕야시장', '방콕야시장태국음식\n4.21/5방문자리뷰 132블로그리뷰 336'], [64, '로향양꼬치 2호점', '로향양꼬치 2호점양꼬치\n4.47/5방문자리뷰 359블로그리뷰 126'], [65, '소풍가는날', '클릭 필요'], [66, '딸랏롯빠이', '클릭 필요'], [67, '원초족본능', '원초족본능족발,보쌈\n4.61/5방문자리뷰 49블로그리뷰 171'], [68, '오드비', '클릭 필요'], [69, '나에게오는길', '나에게오는길카페,디저트\n4.61/5방문자리뷰 109블로그리뷰 200'], [70, '사케바히토리', '사케바히토리일식당\n4.38/5방문자리뷰 29블로그리뷰 44'], [71, '새실정원', '새실정원카페,디저트\n4.4/5방문자리뷰 627블로그리뷰 231'], [72, 'Beck', '클릭 필요'], [73, '동네아저씨치킨', '클릭 필요'], [74, '망원동티라미수 샤로수길점', '망원동티라미수 샤로수길점카페,디저트\n4.28/5방문자리뷰 277블로그리뷰 459'], [75, '황토방', '클릭 필요'], [76, '더고기 서울대본점', '더고기 서울대본점소고기구이\n4.24/5방문자리뷰 187블로그리뷰 226'], [77, '쁘띠크', '클릭 필요'], [78, '오른손푸드카페', '오른손푸드카페브런치\n4.71/5방문자리뷰 42블로그리뷰 55'], [79, 'BANJO', '클릭 필요'], [80, '차이나당', '클릭 필요'], [81, '서울대곱창', '클릭 필요'], [82, '대중주점', '클릭 필요'], [83, '모던보이작업실', '모던보이작업실한식\n4.49/5방문자리뷰 43블로그리뷰 149'], [84, '미카엘', '클릭 필요'], [85, '막걸리카페잡', '막걸리카페잡요리주점\n4.46/5방문자리뷰 56블로그리뷰 110'], [86, '바닐라스카이', '클릭 필요'], [87, '성민양꼬치 2호점', '성민양꼬치 2호점양꼬치\n4.6/5방문자리뷰 110블로그리뷰 79'], [88, '마왕족발 샤로수길점', '클릭 필요'], [89, '할리스커피 서울대사거리점', '클릭 필요'], [90, '현씨공방', '현씨공방전통,민속주점\n4.33/5방문자리뷰 26블로그리뷰 58'], [91, '참새방앗간', '클릭 필요'], [92, '오인자아구찜', '오인자아구찜아귀찜,해물찜\n4.35/5방문자리뷰 381블로그리뷰 309'], [93, '샤로수 흑돈', '샤로수 흑돈돼지고기구이\n4.5/5방문자리뷰 10'], [94, '엔조', '클릭 필요'], [95, '연탄부락 낙성대점', '연탄부락 낙성대점육류,고기요리\n4.44/5방문자리뷰 80블로그리뷰 169'], [96, '고봉식당', '클릭 필요'], [97, '옛날육개장', '클릭 필요'], [98, '엉클비', '클릭 필요'], [99, '스타벅스 서울대입구역점', '클릭 필요'], [100, '고기야', '클릭 필요'], [101, '도스타코스 서울대입구역점', '클릭 필요'], [102, '홍콩반점0410 관악구청점', '클릭 필요'], [103, 'Newyork In Jinbar', '클릭 필요'], [104, '나는남자닭', '클릭 필요'], [105, '신선설농탕 서울대역점', '클릭 필요'], [106, '아비정전', '아비정전와인\n방문자리뷰 2블로그리뷰 5'], [107, '소우주', '클릭 필요'], [108, '카페 블리스', '클릭 필요'], [109, '제리', '클릭 필요'], [110, '만화경', '만화경요리주점\n4.03/5방문자리뷰 16블로그리뷰 116'], [111, '김창일스시', '김창일스시초밥,롤\n4.48/5방문자리뷰 57블로그리뷰 112'], [112, '코젤다크하우스 샤로수길점', '코젤다크하우스 샤로수길점맥주,호프\n4.27/5방문자리뷰 134블로그리뷰 106'], [113, '한우육회마을 2호점', '한우육회마을 2호점소고기구이\n4.52/5방문자리뷰 48블로그리뷰 28'], [114, '깐족깐족', '클릭 필요'], [115, '딱좋아', '클릭 필요'], [116, '미스리부자아줌마', '미스리부자아줌마족발,보쌈\n4.3/5방문자리뷰 144블로그리뷰 233'], [117, '스월링', '클릭 필요'], [118, '사시사철 흑염소오리', '사시사철 흑염소오리오리요리\n4.34/5방문자리뷰 45블로그리뷰 51'], [119, '낙성기사식당', '낙성기사식당기사식당\n4.24/5방문자리뷰 132블로그리뷰 71'], [120, '생활맥주 서울대입구역점', '클릭 필요'], [121, '화상손만두', '클릭 필요'], [122, '무삥과 팟타이', '클릭 필요'], [123, '외래향 서울대점', '외래향 서울대점중식당\n4.38/5방문자리뷰 473블로그리뷰 238'], [124, '이상범스시', '이상범스시초밥,롤\n4.38/5방문자리뷰 169블로그리뷰 58'], [125, '탐앤탐스 서울대입구점', '클릭 필요'], [126, '정육식당 솔', '정육식당 솔정육식당\n4.25/5방문자리뷰 32블로그리뷰 64'], [127, '더은교', '더은교베이커리\n4.52/5방문자리뷰 195블로그리뷰 317'], [128, '도모다찌', '클릭 필요'], [129, '잇쇼쿠', '클릭 필요'], [130, '엘리펀트키친', '클릭 필요'], [131, '정가네 감자탕', '클릭 필요'], [132, '마담봉봉', '클릭 필요'], [133, '육회포차', '클릭 필요'], [134, '사운드마인드', '사운드마인드맥주,호프\n4.81/5방문자리뷰 18블로그리뷰 35'], [135, '우동요츠야', '우동요츠야우동,소바\n4.27/5방문자리뷰 140블로그리뷰 54']]

# %%
review_list_2 = review_list
error_count=0
for li in review_list:
    if li[2] == "클릭 필요":
        try:
            now_rest = li[1]
            driver = webdriver.Chrome("./chromedriver\/chromedriver.exe")
            driver.get("https://map.naver.com/v5/search")
            time.sleep(3)
            search_box = driver.find_element_by_xpath('/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div[1]/div/input')
            search_box.send_keys(now_rest)
            search_box.send_keys(Keys.ENTER)
            time.sleep(3)
            driver.find_element_by_xpath('//*[@id="container"]/shrinkable-layout/div/app-base/search-layout/div[1]/combined-search-list/salt-search-list/nm-external-frame-bridge').click()
            driver.switch_to.frame("searchIframe")
            click_name = driver.find_elements_by_xpath('/html/body/div[3]/div/div/div[1]/ul/li/div[2]/div[1]/a/span[1]')
            text_name = []
            for i in range(len(click_name)):
                text_name.append(click_name[i].text)
            adress = driver.find_elements_by_xpath('/html/body/div[3]/div/div/div[1]/ul/li/div[2]/div[2]/span/a/span[1]')
            for i in range(len(adress)):
                adress[i] = adress[i].text
            data = [] 
            for x, y in zip(text_name, adress):
                data.append([x, y])
            def rest_index(now_rest,list):
                for x in list:
                    if x[0]==now_rest and "관악구" in x[1]:
                        return list.index(x)
            time.sleep(2)
            click_name[rest_index(now_rest, data)].click()
            time.sleep(4)
            driver.switch_to.default_content()
            driver.switch_to.frame("entryIframe")
            review_list_2[review_list.index(li)][2] = driver.find_element_by_xpath('//*[@id="app-root"]/div/div[2]/div[1]/div/div/div[1]').text
            driver.quit()
        except:
            error_count+=1
            driver.quit()
print(review_list_2)
print(error_count)
# Out:
# [[0, '동경산책', '동경산책일식당\n4.44/5방문자리뷰 281블로그리뷰 1024'], [1, '서울테이블', '클릭 필요'], [2, '황홀경', '황홀경브런치\n4.42/5방문자리뷰 274블로그리뷰 616'], [3, '텐동요츠야', '텐동요츠야일식당\n4.33/5방문자리뷰 567블로그리뷰 1615'], [4, '모힝 낙성대점', '모힝 낙성대점양식\n4.65/5방문자리뷰 1,904블로그리뷰 1726'], [5, '박명주브라더', '박명주브라더닭볶음탕\n4.29/5방문자리뷰 282블로그리뷰 356'], [6, '에그썸', '에그썸브런치\n4.36/5방문자리뷰 296블로그리뷰 883'], [7, '온고지신', '온고지신카페,디저트\n4.48/5방문자리뷰 299블로그리뷰 376'], [8, '마이무', '마이무스테이크,립\n4.57/5방문자리뷰 2,229블로그리뷰 1813'], [9, '프랑스홍합집', '프랑스홍합집프랑스음식\n4.43/5방문자리뷰 450블로그리뷰 686'], [10, '오지 편한식당', '오지 편한식당요리주점\n4.67/5방문자리뷰 63블로그리뷰 169'], [11, '용마커피', '용마커피카페\n4.35/5방문자리뷰 214블로그리뷰 158'], [12, '쥬벤쿠바', '쥬벤쿠바양식\n4.67/5방문자리뷰 844블로그리뷰 537'], [13, '맨프롬오키나와', '맨프롬오키나와바(BAR)\n4.25/5방문자리뷰 32블로그리뷰 45'], [14, '메이드바이아린', '메이드바이아린베이커리\n4.52/5방문자리뷰 138블로그리뷰 249'], [15, '옷살', '옷살인도음식\n4.52/5방문자리뷰 252블로그리뷰 413'], [16, '모다모다', '클릭 필요'], [17, '시골집', '클릭 필요'], [18, '카페프레임', '카페프레임카페,디저트\n4.37/5방문자리뷰 88블로그리뷰 205'], [19, '제주상회', '클릭 필요'], [20, '더멜팅팟', '더멜팅팟햄버거\n4.4/5방문자리뷰 180블로그리뷰 619'], [21,
# ...

# %%
x=[0, '동경산책', '동경산책일식당\n4.44/5방문자리뷰 281블로그리뷰 1024']
data = x[2][len(x[1]):]
data2=data
print(data.split('\n'))
# Out:
# ['일식당', '4.44/5방문자리뷰 281블로그리뷰 1024']

# %%
import re
review_list_3=review_list_2
list_for_pd = []
for x in review_list_3:
    if x[2] != "클릭 필요":
        data = x[2][len(x[1]):]
        data2=data
        business=data2.split('\n')[0]
        p_visit = re.compile(r'(?<=방문자리뷰\s).+(?=블로그리뷰)')
        p_blog = re.compile(r'(?<=블로그리뷰\s).+')
        p_rating = re.compile(r'(?<=\n).+(?=/5)')
        m1=p_rating.search(data)
        m2=p_visit.search(data)
        m3=p_blog.search(data)
        if m1 == None:
            rating = 'None'
        else:
            rating = float(m1.group(0))
        if m2 == None:
            visit = 'None'
        else:
            visit = int(m2.group(0).replace(',',''))
        if m3 == None:
            blog = 'None'
        else:
            blog = int(m3.group(0).replace(',',''))
        list_for_pd.append([x[1],business,rating, visit, blog])
print(list_for_pd)
# Out:
# [['동경산책', '일식당', 4.44, 281, 1024], ['황홀경', '브런치', 4.42, 274, 616], ['텐동요츠야', '일식당', 4.33, 567, 1615], ['모힝 낙성대점', '양식', 4.65, 1904, 1726], ['박명주브라더', '닭볶음탕', 4.29, 282, 356], ['에그썸', '브런치', 4.36, 296, 883], ['온고지신', '카페,디저트', 4.48, 299, 376], ['마이무', '스테이크,립', 4.57, 2229, 1813], ['프랑스홍합집', '프랑스음식', 4.43, 450, 686], ['오지 편한식당', '요리주점', 4.67, 63, 169], ['용마커피', '카페', 4.35, 214, 158], ['쥬벤쿠바', '양식', 4.67, 844, 537], ['맨프롬오키나와', '바(BAR)', 4.25, 32, 45], ['메이드바이아린', '베이커리', 4.52, 138, 249], ['옷살', '인도음식', 4.52, 252, 413], ['카페프레임', '카페,디저트', 4.37, 88, 205], ['더멜팅팟', '햄버거', 4.4, 180, 619], ['토끼네마굿간', '이탈리아음식', 4.62, 757, 352], ['모단걸응접실', '양식', 4.13, 60, 372], ['도리도리하찌 닭도리탕', '닭볶음탕', 4.21, 56, 366], ['아띠85도씨베이커리', '베이커리', 4.35, 374, 356], ['순보보', '한식', 4.49, 79, 170], ['코코미', '일식당', 4.27, 241, 1006], ['미각담다', '한식', 4.28, 25, 55], ['오늘그대와', '스파게티,파스타전문', 4.34, 174, 403], ['우리가참순대', '순대,순댓국', 4.43, 199, 313], ['혼네', '이자카야', 4.46, 84, 148], ['라티놀', '종합분식', 4.34, 184, 286], ['펭귄제과', '케이크전문', 4.
# ...
